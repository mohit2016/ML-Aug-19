# %%
from keras.datasets import fashion_mnist
# Out:
# Using TensorFlow backend.

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %%
import keras
from keras.layers import Dense, Conv2D, MaxPool2D, Flatten, Dropout
from keras.models import Sequential
from keras.utils import to_categorical
from keras.preprocessing import image
import matplotlib.pyplot as plt
from keras.optimizers import Adam
from keras.models import load_model

# %%
def drawImg(img):
    plt.imshow(img, cmap="gray")
    plt.show()

# %%
for i in range(10):
    drawImg(x_train[i])

# %%
model = Sequential()
model.add(Conv2D(32, (3,3), activation="relu", input_shape = (28,28,1)))
model.add(MaxPool2D( pool_size=(2, 2)))

model.add(Conv2D(64, (3,3), activation="relu"))
model.add(MaxPool2D( pool_size=(2, 2)))

model.add(Conv2D(128, (3,3), activation="relu"))
model.add(MaxPool2D( pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation="relu"))
model.add(Dropout(rate=0.3))
model.add(Dense(10, activation="softmax"))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Mohit Uniyal\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Mohit Uniyal\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 128)         73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 110,474
# Trainable params: 110,474
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
y_train = to_categorical(y_train)
y_train.shape
# Out:
# (60000, 10)

# %%
y_train.shape
# Out:
# (60000, 10)

# %%
y_test = to_categorical(y_test)

# %%
x_test= x_test.reshape((10000,28,28,1))

# %%
hist = model.fit(x_test, y_test, batch_size=32, epochs=10, validation_split=0.1,
                 shuffle=True)
# Out:
# WARNING:tensorflow:From C:\Users\Mohit Uniyal\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 9000 samples, validate on 1000 samples
# Epoch 1/10
# 9000/9000 [==============================] - 7s 791us/step - loss: 1.4181 - acc: 0.6562 - val_loss: 0.6168 - val_acc: 0.7650
# Epoch 2/10
# 9000/9000 [==============================] - 6s 667us/step - loss: 0.6211 - acc: 0.7781 - val_loss: 0.5429 - val_acc: 0.8050
# Epoch 3/10
# 9000/9000 [==============================] - 6s 673us/step - loss: 0.5297 - acc: 0.8090 - val_loss: 0.4857 - val_acc: 0.8220.5305 - acc: 0.808
# Epoch 4/10
# 9000/9000 [==============================] - 6s 660us/step - loss: 0.4605 - acc: 0.8279 - val_loss: 0.4616 - val_acc: 0.8350
# Epoch 5/10
# 9000/9000 [==============================] - 6s 654us/step - loss: 0.4257 - acc: 0.8420 - val_loss: 0.4641 - val_acc: 0.8270
# Epoch 6/10
# 9000/9000 [==============================] - 6s 657us/step - loss: 0.3987 - acc: 0.8560 - val_loss: 0.5062 - val_acc: 0.8190
# Epoch 7/10
# 9000/9000 [==============================] - 6s 664us/step - loss: 0.3566 - acc: 0.8714 - val_loss: 0.4819 - val_acc: 0.8320
# Epoch 8/10
# 9000/9000 [==============================] - 6s 656us/step - loss: 0.3390 - acc: 0.8736 - val_loss: 0.4686 - val_acc: 0.8360
# Epoch 9/10
# 9000/9000 [==============================] - 6s 703us/step - loss: 0.3091 - acc: 0.8843 - val_loss: 0.4608 - val_acc: 0.8370
# Epoch 10/10
# 9000/9000 [==============================] - 6s 689us/step - loss: 0.2957 - acc: 0.8888 - val_loss: 0.4574 - val_acc: 0.8310

# %%
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])

# %%
model.save("new_model.h5")

# %%
abc = load_model("new_model.h5")

# %%
import numpy as np

# %%
img = image.load_img("images/cody.jpg", target_size=(28,28,1), color_mode="grayscale")
img = image.img_to_array(img)
img = np.expand_dims(img, axis=0)

# %%
img.shape
# Out:
# (1, 28, 28, 1)

# %%
abc.predict_classes(img)
# Out:
# array([8], dtype=int64)
